# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("C:/Users/fjdks/Desktop/chaewon_docs/study/KaggleStudy/4_Credit/train.csv")
test=pd.read_csv("C:/Users/fjdks/Desktop/chaewon_docs/study/KaggleStudy/4_Credit/test.csv")
submit=pd.read_csv("C:/Users/fjdks/Desktop/chaewon_docs/study/KaggleStudy/4_Credit/submission.csv")

# %%
train.head()
# Out:
#    store_id        date      time     card_id  amount  installments  \
# 0         0  2016-12-14  18:05:31  d297bba73f       5           NaN
# 1         0  2016-12-14  18:05:54  d297bba73f      -5           NaN
# 2         0  2016-12-19  12:42:31  0880849c05     144           NaN
# 3         0  2016-12-19  12:48:08  8b4f9e0e95      66           NaN
# 4         0  2016-12-19  13:31:08  7ad237eed0      24           NaN
#
#    days_of_week  holyday
# 0             2        0
# 1             2        0
# 2             0        0
# 3             0        0
# 4             0        0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3362796 entries, 0 to 3362795
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   store_id      int64
#  1   date          object
#  2   time          object
#  3   card_id       object
#  4   amount        int64
#  5   installments  float64
#  6   days_of_week  int64
#  7   holyday       int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 205.2+ MB

# %%
train['installments']=train['installments'].fillna(0)
train.head()
# Out:
#    store_id        date      time     card_id  amount  installments  \
# 0         0  2016-12-14  18:05:31  d297bba73f       5           0.0
# 1         0  2016-12-14  18:05:54  d297bba73f      -5           0.0
# 2         0  2016-12-19  12:42:31  0880849c05     144           0.0
# 3         0  2016-12-19  12:48:08  8b4f9e0e95      66           0.0
# 4         0  2016-12-19  13:31:08  7ad237eed0      24           0.0
#
#    days_of_week  holyday
# 0             2        0
# 1             2        0
# 2             0        0
# 3             0        0
# 4             0        0

# %%
train=pd.get_dummies(train,columns=['days_of_week'])
train.head()
# Out:
#    store_id        date      time     card_id  amount  installments  holyday  \
# 0         0  2016-12-14  18:05:31  d297bba73f       5           0.0        0
# 1         0  2016-12-14  18:05:54  d297bba73f      -5           0.0        0
# 2         0  2016-12-19  12:42:31  0880849c05     144           0.0        0
# 3         0  2016-12-19  12:48:08  8b4f9e0e95      66           0.0        0
# 4         0  2016-12-19  13:31:08  7ad237eed0      24           0.0        0
#
#    days_of_week_0  days_of_week_1  days_of_week_2  days_of_week_3  \
# 0               0               0               1               0
# 1               0               0               1               0
# 2               1               0               0               0
# 3               1               0               0               0
# 4               1               0               0               0
#
#    days_of_week_4  days_of_week_5  days_of_week_6
# 0               0               0               0
# ...

# %%
print(np.unique(train['holyday']))
# Out:
# [0 1]

# %%
train=train.drop(axis=1,labels=['card_id'])

# %%
train.head()
# Out:
#    store_id        date      time  amount  installments  holyday  \
# 0         0  2016-12-14  18:05:31       5           0.0        0
# 1         0  2016-12-14  18:05:54      -5           0.0        0
# 2         0  2016-12-19  12:42:31     144           0.0        0
# 3         0  2016-12-19  12:48:08      66           0.0        0
# 4         0  2016-12-19  13:31:08      24           0.0        0
#
#    days_of_week_0  days_of_week_1  days_of_week_2  days_of_week_3  \
# 0               0               0               1               0
# 1               0               0               1               0
# 2               1               0               0               0
# 3               1               0               0               0
# 4               1               0               0               0
#
#    days_of_week_4  days_of_week_5  days_of_week_6
# 0               0               0               0
# 1               0               0               0
# ...

# %%
train['datetime']=np.NaN
train['datetime']=train['date']+train['time']

# %%
train.head()
# Out:
#    store_id        date      time  amount  installments  holyday  \
# 0         0  2016-12-14  18:05:31       5           0.0        0
# 1         0  2016-12-14  18:05:54      -5           0.0        0
# 2         0  2016-12-19  12:42:31     144           0.0        0
# 3         0  2016-12-19  12:48:08      66           0.0        0
# 4         0  2016-12-19  13:31:08      24           0.0        0
#
#    days_of_week_0  days_of_week_1  days_of_week_2  days_of_week_3  \
# 0               0               0               1               0
# 1               0               0               1               0
# 2               1               0               0               0
# 3               1               0               0               0
# 4               1               0               0               0
#
#    days_of_week_4  days_of_week_5  days_of_week_6            datetime
# 0               0               0               0  2016-12-1418:05:31
# ...

# %%
train=train.drop(axis=1,labels=['time','date'])
train.head()
# Out:
#    store_id  amount  installments  holyday  days_of_week_0  days_of_week_1  \
# 0         0       5           0.0        0               0               0
# 1         0      -5           0.0        0               0               0
# 2         0     144           0.0        0               1               0
# 3         0      66           0.0        0               1               0
# 4         0      24           0.0        0               1               0
#
#    days_of_week_2  days_of_week_3  days_of_week_4  days_of_week_5  \
# 0               1               0               0               0
# 1               1               0               0               0
# 2               0               0               0               0
# 3               0               0               0               0
# 4               0               0               0               0
#
#    days_of_week_6            datetime
# 0               0  2016-12-1418:05:31
# 1               0  2016-12-1418:05:54
# ...
